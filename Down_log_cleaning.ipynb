# %%
# %qtconsole

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('down_log.csv')

# %%
df.head()
# Out:
#            uid device     song_id            song_name singer  paid_flag
# 0          NaN     ar   3602398.0                   意外    薛之谦        0.0
# 1  168175769.0     ar     71969.0                爱拼才会赢    叶启田        0.0
# 2  168084945.0     ar   6482561.0                 遥远的她    张学友        0.0
# 3  168287798.0     ar   7111240.0           如果能重来(DJ版)     温喃        0.0
# 4  168446565.0     ar  11922814.0  火星人来过-(《火星情报局2》主题曲)    薛之谦        0.0

# %%
song_dict = df.groupby('song_id').first()['song_name']

# %%
song_dict.to_csv('song_dict.csv')

# %%
import pickle
with open('song_dict.pkl', 'wb') as f:
    pickle.dump(song_dict.to_dict(), f)

# %%
df.uid.isnull().sum()
# Out:
# 456736

# %%
1.0 * df.uid.isnull().sum()/df.shape[0] *100
# Out:
# 6.799747802389625

# %%
df.uid.nunique()
# Out:
# 197744

# %%
df.uid.dtype
# Out:
# dtype('float64')

# %%
df.groupby('device').size().reset_index(name = "counts").sort_values("counts", ascending = False)
# Out:
#                                  device   counts
# 223                                  ar  5419392
# 225                                  ip   840955
# 224                                 ar    356247
# 226                                 ip     92358
# 1160                                薛之谦      293
# 864                                  梦然      210
# 193                              TFBOYS      154
# 598                                 庄心妍      141
# 278                                 云菲菲      137
# 1065                               经典老歌      128
# 971                                  王冕      126
# 1313                                 铃声      121
# 903                                 汪苏泷      115
# 257                                乌兰图雅      110
# 1110                             苏勒亚其其格      101
# 653                                 张碧晨       92
# 826                                  杨洋       73
# 328                                儿童歌曲       68
# ...

# %%
df.device = df.device.str.strip()

# %%
device_count = df.groupby('device').size().reset_index(name = "counts").sort_values("counts", ascending = False)

# %%
device_count['percentage'] = device_count.counts/device_count.counts.sum()*100

# %%
device_count
# Out:
#                               device   counts  percentage
# 198                               ar  5775639   85.987648
# 199                               ip   933313   13.895153
# 978                              薛之谦      320    0.004764
# 730                               梦然      227    0.003380
# 172                           TFBOYS      164    0.002442
# 512                              庄心妍      150    0.002233
# 245                              云菲菲      147    0.002189
# 1109                              铃声      136    0.002025
# 899                             经典老歌      136    0.002025
# 819                               王冕      131    0.001950
# 227                             乌兰图雅      120    0.001787
# 764                              汪苏泷      117    0.001742
# 936                           苏勒亚其其格      114    0.001697
# 553                              张碧晨      103    0.001533
# 697                               杨洋       74    0.001102
# ...

# %%
df[df.isnull().any(axis = 1)].head()
# Out:
#             uid device    song_id song_name singer  paid_flag
# 0           NaN     ar  3602398.0        意外    薛之谦        0.0
# 6   168527791.0     ip  3759609.0       NaN    NaN        0.0
# 10  168433247.0     ip   625294.0       NaN    NaN        0.0
# 12  168527791.0     ip   113901.0       NaN    NaN        0.0
# 22  168433247.0     ip  9919225.0       NaN    NaN        0.0

# %%
1.0 * df.isnull().any(axis = 1).sum() / df.shape[0]
# Out:
# 0.19467675457108169

# %% [markdown]
# ### Clean Data

# %%
df.dropna(inplace = True)

# %%
df.describe()
# Out:
#                 uid       song_id  paid_flag
# count  5.409320e+06  5.409320e+06  5409320.0
# mean   1.271758e+08  5.851104e+06        0.0
# std    6.957643e+07  6.445421e+06        0.0
# min    0.000000e+00  5.422100e+04        0.0
# 25%    4.653227e+07  8.872880e+05        0.0
# 50%    1.680622e+08  4.367266e+06        0.0
# 75%    1.685887e+08  6.861545e+06        0.0
# max    1.692623e+08  1.591132e+09        0.0

# %%
df.uid.sort_values()[1]
# Out:
# 168175769.0

# %% [markdown]
# 0 probably is a special value for uid to indicate unidentified or admin

# %%
mask = df.uid != 0

# %%
df = df[mask]

# %%
df.describe()
# Out:
#                 uid       song_id  paid_flag
# count  5.269990e+06  5.269990e+06  5269990.0
# mean   1.305381e+08  5.873245e+06        0.0
# std    6.730492e+07  6.454868e+06        0.0
# min    1.040570e+05  5.422100e+04        0.0
# 25%    1.559482e+08  8.965180e+05        0.0
# 50%    1.681097e+08  4.382418e+06        0.0
# 75%    1.686053e+08  6.863819e+06        0.0
# max    1.692623e+08  1.591132e+09        0.0

# %%
down_freq = df.groupby(['uid', 'song_id']).size().reset_index()

# %%
down_freq.head()
# Out:
#         uid    song_id  0
# 0  104057.0   705790.0  1
# 1  104057.0  1009976.0  1
# 2  104057.0  2926987.0  1
# 3  104057.0  2939508.0  1
# 4  104057.0  2975785.0  1

# %%
down_freq.describe()
# Out:
#                 uid       song_id             0
# count  4.021810e+06  4.021810e+06  4.021810e+06
# mean   1.545547e+08  5.828974e+06  1.310353e+00
# std    4.380773e+07  6.394032e+06  2.961040e+00
# min    1.040570e+05  5.422100e+04  1.000000e+00
# 25%    1.678595e+08  8.713082e+05  1.000000e+00
# 50%    1.682971e+08  4.345256e+06  1.000000e+00
# 75%    1.686993e+08  6.857210e+06  1.000000e+00
# max    1.692623e+08  1.591132e+09  1.275000e+03

# %%
down_freq.to_csv("down_freq.csv", index= False)
